# %%
import json
import requests
import pandas as pd
import re
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize
#Word cloud
from os import path
from PIL import Image
import matplotlib.pyplot as plt
# from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import coo_matrix

# %%
r = requests.get('http://13.234.233.153:8000/cxaudiocore/').json()

# %%
from pandas.io.json import json_normalize
data = json_normalize(r)

# %%
print (data)
# Out:
#     agent_id  agent_name                    agent_sentiment audio_duration  \
# 0       4292        None   0.540816326530612200000000000000           None
# 1       4414       Seema   0.076226551226551230000000000000           None
# 2       1893        None   0.450420168067226840000000000000           None
# 3       2635        None   0.367261904761904730000000000000           None
# 4       4372        None   0.405714285714285700000000000000           None
# 5       3923        None   0.222564102564102580000000000000           None
# 6       4376        None   0.052579365079365080000000000000           None
# 7       4366        None  -0.250000000000000000000000000000           None
# 8       4400        None   0.187135780885780870000000000000           None
# 9     988998        None   0.293587662337662370000000000000           None
# 10      2281        None   0.316694033935413230000000000000           None
# ...

# %%
print(len(data))
# Out:
# 112

# %%
data_agg=data.loc[67:112]

# %%
print(data_agg)
# Out:
#     agent_id agent_name                    agent_sentiment audio_duration  \
# 67         2      Robot   0.276190476190476200000000000000        0:04:04
# 68         2      Robot   0.337343750000000000000000000000        0:04:39
# 69      4497       None   0.227658730158730170000000000000        0:09:56
# 70      4376       None   0.250000000000000000000000000000        0:01:37
# 71      4376       None   0.283333333333333300000000000000        0:02:41
# 72      4415       None   0.461904761904761900000000000000        0:03:15
# 73      4384       None   0.238739177489177470000000000000        0:03:56
# 74      4233       None   0.346765615337043900000000000000        0:03:55
# 75      4339       None   0.392857142857142850000000000000        0:05:14
# 76      3593       None   0.222857142857142860000000000000        0:07:01
# 77      4464       None   0.167016922471467930000000000000        0:09:48
# 78      4445       None   0.397142857142857130000000000000        0:01:27
# ...

# %%
data.columns
# Out:
# Index(['agent_id', 'agent_name', 'agent_sentiment', 'audio_duration',
#        'audio_file_path', 'audio_id', 'combined_transcription', 'conf_results',
#        'created_date', 'customer_name', 'customer_sentiment',
#        'energy_variance', 'intent.negative', 'intent.positive',
#        'negative_keyword', 'negative_phrases', 'positive_keyword',
#        'positive_phrases', 'raw_transcription', 'serialized_transcription',
#        'speakertagging_result', 'tone_emotion_result', 'updated_date'],
#       dtype='object')

# %%
data_negative = data['intent.negative'][0:112]

# %%
print(len(data_negative.dropna()))
# Out:
# 39

# %%
data_positive = data['intent.positive'][0:112]
print(len(data_positive.dropna()))
# Out:
# 73
